# %%
import stock_analysis as sa
from ipysheet import from_dataframe as fd

# %%
sa.help()
# Out:
# The stock analysis library includes the following functionality:
# Watchlist class: a watchlist that stores stocks with their priorities
# Watchlist functionality: push, front, remove, pop, view
# get_metrics(ticker, metrics_to_display): display a metric for a given stock
# quick_view(ticker): view various important metrics pertaining to a stock
# daily_view(ticker,num_days,display=[]): view daily changes in multiples or other metrics
# competitor_view(ticker,specced_comps,category,filter_revenue): view analysis on competitors
# quick_valuation(ticker,ann_ebitda_growth,future_ebitda_multiple,num_yrs,share_change,cash_change,debt_change)
# quick_screener_fg(revenue_growth, num_yrs): screen for fast growers at low multiples
# quick_screener_bs(): screen for stocks with a strong balance sheet

# %% [markdown]
# # Daily Screens

# %%
sa.quick_screener_fg(output=True)
# Out:
# Tickers at 0 : []
# Tickers at 0 : []
# Tickers at 0 : []
# Tickers at 0 : []
# Tickers at 0 : []
# Ticker: AAAP
# 	EBITDA Multiple: -72.22
# 	PS: 9.135
# 	Revenue Growth: 0.2795549796298745
# BUY: AAAP
# Ticker: AACH
# 	EBITDA Multiple: -43.786
# 	PS: 0.116
# 	Revenue Growth: 0.4539853893346986
# BUY: AACH
# Ticker: AAIC
# 	EBITDA Multiple: 285.364
# 	PS: 7.806
# 	Revenue Growth: 0.19897613254042307
# Ticker: AAL
# 	EBITDA Multiple: 8.208
# 	PS: 0.275
# 	Revenue Growth: 0.16709523496887732
# Ticker: AAMC
# 	EBITDA Multiple: -1.607
# 	PS: 1.252
# 	Revenue Growth: 0.8575205264392829
# BUY: AAMC
# Ticker: AAOI
# 	EBITDA Multiple: -13.862
# 	PS: 1.252
# 	Revenue Growth: 0.42034931272183673
# BUY: AAOI
# Ticker: AAPL
# 	EBITDA Multiple: 25.588
# 	PS: 6.995
# 	Revenue Growth: 0.2214846347160147
# Ticker: ABC
# 	EBITDA Multiple: -4.207
# 	PS: 0.104
# 	Revenue Growth: 0.15379257018412368
# BUY: ABC
# Ticker: ABCB
# 	EBITDA Multiple: 15.75
# 	PS: 4.335
# 	Revenue Growth: 0.1831818513077914
# ...

# %%
import pickle 
f = open('saved_fg_screen')
pickle.dump()

# %%
sa.quick_screener_bs(output=True)
# Out:
# Ticker A
# 	High Cash: False
# 	Low PTB: False
# 	5 YR Decreasing Debt: True
# 	5 YR Increasing Cash: False
# Ticker AA
# 	High Cash: False
# 	Low PTB: True
# 	5 YR Decreasing Debt: False
# 	5 YR Increasing Cash: True
# Ticker AAAB
# Unknown error. Please analyze manually.
# Ticker AAAGY
# Unknown error. Please analyze manually.
# Ticker AAAP
# 	High Cash: True
# 	Low PTB: False
# 	5 YR Decreasing Debt: True
# 	5 YR Increasing Cash: True
# Ticker AABC
# Unknown error. Please analyze manually.
# Ticker AAC.U
# 	High Cash: False
# 	Low PTB: False
# 	5 YR Decreasing Debt: False
# 	5 YR Increasing Cash: False
# Ticker AAC1
# Unknown error. Please analyze manually.
# Ticker AACB
# Unknown error. Please analyze manually.
# Ticker AACC
# 	High Cash: False
# 	Low PTB: False
# 	5 YR Decreasing Debt: False
# 	5 YR Increasing Cash: True
# Ticker AACE
# Unknown error. Please analyze manually.
# Ticker AACG
# 	High Cash: True
# 	Low PTB: False
# 	5 YR Decreasing Debt: False
# ...

# %%
True + True +True
# Out:
# 3
